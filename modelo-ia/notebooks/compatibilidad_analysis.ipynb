# %% [markdown]
# # Análisis de compatibilidad — Encorely Fase 3
#
# Notebook de exploración que consume `analyzer.py` con datos reales de la API Django.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path("..").resolve()))

from src.data_loader import load_all_dataframes
from src.analyzer import run_full_analysis

data = load_all_dataframes()
results = run_full_analysis(data)
results
